# %% [markdown]
# Level 1
# Task 1
# Task: Top Cuisines
# 1)
# Determine the top three mos
# common cuisines in the dataset2)  .
# Calculate the percentage of
# restaurants that serve each of the top
# cuisines.

# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
data = pd.read_csv(r"C:\Users\LENOVO\Downloads\Dataset .csv ")

# %%
data
# Out:
#       Restaurant ID           Restaurant Name  Country Code              City  \
# 0           6317637          Le Petit Souffle           162       Makati City
# 1           6304287          Izakaya Kikufuji           162       Makati City
# 2           6300002    Heat - Edsa Shangri-La           162  Mandaluyong City
# 3           6318506                      Ooma           162  Mandaluyong City
# 4           6314302               Sambo Kojin           162  Mandaluyong City
# ...             ...                       ...           ...               ...
# 9546        5915730               Naml۱ Gurme           208         ��stanbul
# 9547        5908749              Ceviz A��ac۱           208         ��stanbul
# 9548        5915807                     Huqqa           208         ��stanbul
# 9549        5916112               A���k Kahve           208         ��stanbul
# 9550        5927402  Walter's Coffee Roastery           208         ��stanbul
#
# ...

# %%
cuisines_data = data["Cuisines"]

# %%
cuisines_counts = cuisines_data.value_counts()

# %%
Top_cuisines = cuisines_counts.head(3)

# %%
Top_cuisines
# Out:
# Cuisines
# North Indian             936
# North Indian, Chinese    511
# Chinese                  354
# Name: count, dtype: int64

# %%
total_restaurant = len(data)

# %%
total_restaurant
# Out:
# 9551

# %%
percentage = (Top_cuisines/total_restaurant)*100

# %%
plt.bar(percentage.index , percentage.values)
plt.xlabel('Cuisines')
plt.ylabel('percentage')
plt.title("Top Three Cuisines in the Dataset")
plt.show()

# %%
plt.pie(Top_cuisines, labels = Top_cuisines.index, autopct='%1.1f%%')
plt.title("Top Three Cuisines in the Dataset")
plt.show()

# %% [markdown]
# Level 1
# Task 2
# Task: City Analysis
# 1)
# Identify the city with the highest number oof restaurants in the dataset2) .
# Calculate the average rating   r
# restaurants in eachty
#  cy.
# Determine the city with the hiest
# average rating.

# %%
restaurants_count = data.groupby('City')['Restaurant ID'].count()
city_with_highest_restaurants = restaurants_count.idxmax()
print("City with Highest Number of Restaurants: ",city_with_highest_restaurants)
# Out:
# City with Highest Number of Restaurants:  New Delhi

# %%
average_rating = data.groupby('City')['Aggregate rating'].mean()

# %%
average_rating.plot(kind = 'bar' , figsize=(26,8))
plt.xlabel('city')
plt.ylabel('Average rating')
plt.title("Average Rating for restaurants in each city")
plt.show()

# %%
print("city with highest average rating: ",average_rating.idxmax())
# Out:
# city with highest average rating:  Inner City

# %% [markdown]
# level 1
# Task3:
# Price Range Distribution
# 1)
# Create a histogram or bar chart t
# visualize the distribution of price rang s
# among the restaurant2) s.
# Calculate the percentage of restaur nts
# in each price range category.

# %%
price_range_counts = data['Price range'].value_counts().sort_index()

# %%
percentage_per_price_range = (price_range_counts/total_restaurant)*100

# %%
plt.bar(price_range_counts.index , price_range_counts.values)
plt.xlabel('price range')
plt.ylabel('Number of Restaurant')
plt.title('Distribution of price range')
plt.show()

# %%
print("percentage of price range in each range category")
print(percentage_per_price_range)
# Out:
# percentage of price range in each range category
# Price range
# 1    46.529159
# 2    32.593446
# 3    14.741912
# 4     6.135483
# Name: count, dtype: float64

# %% [markdown]
# Level 1 Task 4: Online Delivery
# 1)
# Determine the percentage of restaurant
# that offer online delivery2)  .
# Compare the average ratings of restaura ts
# with and without online delivery.

# %%
restaurant_with_online_delivery = data['Has Online delivery'].value_counts().get('Yes', 0)
percentage_with_online_delivery = (restaurant_with_online_delivery/total_restaurant)*100

# %%
print("percentage of restaurant that offer Online Delivery:" , percentage_with_online_delivery)
# Out:
# percentage of restaurant that offer Online Delivery: 25.662234321013504

# %%
average_rating_with_online_delivery = data[data['Has Online delivery']== 'yes']['Aggregate rating'].mean()
average_rating_without_online_delivery = data[data['Has Online delivery']== 'No']['Aggregate rating'].mean()

# %%
print("Average rating of restaurant with online delivery: ",average_rating_with_online_delivery)
print("Average rating of restaurant without online delivery: ",average_rating_without_online_delivery)
# Out:
# Average rating of restaurant with online delivery:  nan
# Average rating of restaurant without online delivery:  2.465295774647887

# %%
labels = ['with online delivery' , 'without online delivery']
average_ratings = [average_rating_with_online_delivery, average_rating_with_online_delivery]

plt.bar(labels,average_ratings)
plt.xlabel('Online Delivery')
plt.ylabel('Average Rating')
plt.title('Comparison of Average Ratings')
plt.show()

# %% [markdown]
# Leve2 Task 1
# Restaurant Chains
# 1 Identify if there are any restaurant chain
# present in the datast
# t2
# Analyze the ratings and popularity  f
# different restaurant chains.

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
data = pd.read_csv(r"C:\Users\LENOVO\Downloads\Dataset .csv")

# %%
data
# Out:
#       Restaurant ID           Restaurant Name  Country Code              City  \
# 0           6317637          Le Petit Souffle           162       Makati City
# 1           6304287          Izakaya Kikufuji           162       Makati City
# 2           6300002    Heat - Edsa Shangri-La           162  Mandaluyong City
# 3           6318506                      Ooma           162  Mandaluyong City
# 4           6314302               Sambo Kojin           162  Mandaluyong City
# ...             ...                       ...           ...               ...
# 9546        5915730               Naml۱ Gurme           208         ��stanbul
# 9547        5908749              Ceviz A��ac۱           208         ��stanbul
# 9548        5915807                     Huqqa           208         ��stanbul
# 9549        5916112               A���k Kahve           208         ��stanbul
# 9550        5927402  Walter's Coffee Roastery           208         ��stanbul
#
# ...

# %%
def analyze_rating_distribution(dataset_path):
    plt.figure(figsize=(8,6))
    plt.hist(data["Aggregate rating"], bins = 10 , edgecolor = "black" , color = "skyblue")
    plt.xlabel("Rating")
    plt.ylabel("Frequency")
    plt.title("Distribution of Ratings")
    plt.grid(True)
    plt.show()
    
    most_common_range = data["Aggregate rating"].mode()[0]
    return most_common_range

dataset_path = "Restaurant.csv"
most_common_rating_range = analyze_rating_distribution(dataset_path)

print(f"The most common rating range is: {most_common_rating_range}")
# Out:
# The most common rating range is: 0.0

# %%
def calculate_average_votes(dataset_path):
    average_votes = data["Votes"].mean()
    return average_votes
dataset_path = "Restaurant.csv"    
average_votes = calculate_average_votes(dataset_path)
print(f"The average number of votes recieved by restaurant is: {average_votes: 2f}")
# Out:
# The average number of votes recieved by restaurant is:  156.909748

# %% [markdown]
# level 2 task 2
# Cuisine Combination
# 1) Identify the most common combinations of cuisines in the dataset.
# 2) Determine if certain cuisine combinations tend to have higher ratings.

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
data = pd.read_csv(r"C:\Users\LENOVO\Downloads\Dataset .csv")

# %%
data
# Out:
#       Restaurant ID           Restaurant Name  Country Code              City  \
# 0           6317637          Le Petit Souffle           162       Makati City
# 1           6304287          Izakaya Kikufuji           162       Makati City
# 2           6300002    Heat - Edsa Shangri-La           162  Mandaluyong City
# 3           6318506                      Ooma           162  Mandaluyong City
# 4           6314302               Sambo Kojin           162  Mandaluyong City
# ...             ...                       ...           ...               ...
# 9546        5915730               Naml۱ Gurme           208         ��stanbul
# 9547        5908749              Ceviz A��ac۱           208         ��stanbul
# 9548        5915807                     Huqqa           208         ��stanbul
# 9549        5916112               A���k Kahve           208         ��stanbul
# 9550        5927402  Walter's Coffee Roastery           208         ��stanbul
#
# ...

# %%
def identify_common_cuisine_combinations (dataset_path):

    cuisine_combinations=data['Cuisines'].str.split(',').explode()
    cuisine_combinations_count = cuisine_combinations.value_counts()

    return cuisine_combinations_count

dataset_path = 'restaurants.csv'
common_cuisine_combinations = identify_common_cuisine_combinations (dataset_path)

print("Most common_combinations of cuisines:")

print(common_cuisine_combinations.head(10))
# Out:
# Most common_combinations of cuisines:
# Cuisines
# North Indian     2992
#  Chinese         1880
#  Fast Food       1314
#  North Indian     968
# Chinese           855
#  Mughlai          780
# Fast Food         672
# Bakery            621
# Cafe              617
#  Italian          530
# Name: count, dtype: int64

# %%
def analyze_cuisine_combinations_and_ratings(dataset_path):
    data['cuisine_combination'] = data['Cuisines'].str.split(",")
    data_exploded = data.explode("cuisine_combination")
    average_ratings_by_combination = data_exploded.groupby('cuisine_combination')['Aggregate rating'].mean()

    sorted_ratings = average_ratings_by_combination.sort_values(ascending=False)
    plt.figure(figsize=(10,6))
    sorted_ratings.head(10).plot(kind = "bar", color = "skyblue")
    plt.xlabel("Cuisine Combination")
    plt.ylabel("Average Rating")
    plt.title("Top 10 Cuisine Combination with Highest Average Ratings")
    plt.xticks(rotation=45, ha = "right")
    plt.grid(True)
    plt.tight_layout()
    plt.show()
    return sorted_ratings

dataset_path = "restaurants.csv"
sorted_ratings = analyze_cuisine_combinations_and_ratings(dataset_path)

print("Average ratings for top 10 cuisine combinations:")
print(sorted_ratings.head(10))
# Out:
# Average ratings for top 10 cuisine combinations:
# cuisine_combination
# Sunda            4.900000
# Scottish         4.700000
#  B�_rek          4.700000
# Cajun            4.700000
#  Caribbean       4.666667
# Taiwanese        4.650000
# Filipino         4.616667
# Ramen            4.600000
# Persian          4.600000
# World Cuisine    4.500000
# Name: Aggregate rating, dtype: float64

# %% [markdown]
# Level 2 Task 3: Geographic Analysis
# 1)
# Plot the locations of restaurants on
# map using longitude and latitude
# coordinate2) s.
# Identify any patterns or cluster  of
# restaurants in specific areas.

# %%
import pandas as pd
import folium

# %%
from sklearn.cluster import KMeans

# %%
data = pd.read_csv(r"C:\Users\LENOVO\Downloads\Dataset .csv")

# %%
data
# Out:
#       Restaurant ID           Restaurant Name  Country Code              City  \
# 0           6317637          Le Petit Souffle           162       Makati City
# 1           6304287          Izakaya Kikufuji           162       Makati City
# 2           6300002    Heat - Edsa Shangri-La           162  Mandaluyong City
# 3           6318506                      Ooma           162  Mandaluyong City
# 4           6314302               Sambo Kojin           162  Mandaluyong City
# ...             ...                       ...           ...               ...
# 9546        5915730               Naml۱ Gurme           208         ��stanbul
# 9547        5908749              Ceviz A��ac۱           208         ��stanbul
# 9548        5915807                     Huqqa           208         ��stanbul
# 9549        5916112               A���k Kahve           208         ��stanbul
# 9550        5927402  Walter's Coffee Roastery           208         ��stanbul
#
# ...

# %%
map_center = [data['Latitude'].iloc[0], data['Longitude'].iloc[0]]
restaurant_map = folium.Map(location=map_center, zoom_start=13)
for index, row in data.iterrows():
    folium.Marker(
        location=[row['Latitude'], row['Longitude']],
        popup=row['Restaurant Name'],
        icon=folium.Icon(icon='cutlery', prefix='fa')
    ).add_to(restaurant_map)

restaurant_map.save('restaurant_map.html')

# %% [markdown]
# Level 2 Task 4: Restaurant Chains
# 1)
# Identify if there are any restaurant chain
# present in the dataset2) .
# Analyze the ratings and popularity of
# different restaurant chains.

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sb

# %%
data = pd.read_csv(r"C:\Users\LENOVO\Downloads\Dataset .csv")

# %%
chain_counts = data['Restaurant Name'].value_counts()

restaurant_chains = chain_counts[chain_counts > 1]

print("Restaurant Chains:")
print(restaurant_chains)
# Out:
# Restaurant Chains:
# Restaurant Name
# Cafe Coffee Day       83
# Domino's Pizza        79
# Subway                63
# Green Chick Chop      51
# McDonald's            48
#                       ..
# Town Hall              2
# Halki Aanch            2
# Snack Junction         2
# Delhi Biryani Hut      2
# Beliram Degchiwala     2
# Name: count, Length: 734, dtype: int64

# %%
chain_stats = data.groupby('Restaurant Name').agg({'Aggregate rating': 'mean', 'Votes': 'sum'})

chain_stats = chain_stats.sort_values(by = 'Aggregate rating', ascending=False)

top_chains = chain_stats.head(10)

print("Top 10 Restaurant Chains:")

print(top_chains)

plt.figure(figsize=(12, 6))
plt.subplot(1, 2, 1)
sb.barplot(x=top_chains.index, y=top_chains['Aggregate rating'], palette= 'Blues')
plt.xticks(rotation=90)
plt.title('Average Rating of Top Chains')

plt.subplot(1, 2, 2)
sb.barplot(x = top_chains.index, y=top_chains['Votes'], palette='Reds')
plt.xticks(rotation=90)
plt.title('Popularity of Top Chains')
plt.tight_layout()
plt.show()
# Out:
# Top 10 Restaurant Chains:
#                                 Aggregate rating  Votes
# Restaurant Name
# Restaurant Mosaic @ The Orient               4.9     85
# Ministry of Crab                             4.9    203
# Miann                                        4.9    281
# Shorts Burger and Shine                      4.9    820
# Milse                                        4.9    754
# Yellow Dog Eats                              4.9   1252
# Duck & Waffle                                4.9    706
# Gaga Manjero                                 4.9     95
# Mirchi And Mime                              4.9   3244
# McGuire's Irish Pub & Brewery                4.9   2238

# %% [markdown]
# Level 3 Task 1: Restaurant Reviews
# 1) Analyze the text reviews to identify the mos
# common positive and negative keyword
# 2)
# Calculate the average length of reviews   d
# explore if there is a relationship wet  en
# review length and rating.

# %%
import nltk
from nltk.corpus import stopwords
from nltk.tokenize import word_tokenize, sent_tokenize
from nltk.stem import WordNetLemmatizer

# %%
nltk.download('punkt')
nltk.download('wordnet')
nltk.download('stopwords')
# Out:
# [nltk_data] Downloading package punkt to
# [nltk_data]     C:\Users\LENOVO\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package wordnet to
# [nltk_data]     C:\Users\LENOVO\AppData\Roaming\nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\LENOVO\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# True

# %%
reviews = [
    "The food was excellent and the service was great. Higly recommended!",
    "Terrible experience. The food was cold and the staff was rude.",
    "Amazing ambiance and delicious food.Will definetly come back again.",
    "Overpriced menu and meidocre food quality. Disappointed with the experience."
]

# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
data_sorted_by_votes = data.sort_values(by='Votes', ascending = False)

restaurant_highest_votes = data_sorted_by_votes.iloc[0]

restaurant_lowest_votes = data_sorted_by_votes.iloc[-1]

print("Restaurant with Highest Number of Votes")
print(restaurant_highest_votes)

print("Restaurant with Lowest Number of Votes")
print(restaurant_lowest_votes)
# Out:
# Restaurant with Highest Number of Votes
# Restaurant ID                                                       51705
# Restaurant Name                                                      Toit
# Country Code                                                            1
# City                                                            Bangalore
# Address                 298, Namma Metro Pillar 62, 100 Feet Road, Ind...
# Locality                                                      Indiranagar
# Locality Verbose                                   Indiranagar, Bangalore
# Longitude                                                       77.640709
# Latitude                                                        12.979166
# Cuisines                                         Italian, American, Pizza
# Average Cost for two                                                 2000
# Currency                                               Indian Rupees(Rs.)
# ...

# %%
 plt.figure(figsize=(8,6))
plt.scatter(data['Votes'], data['Aggregate rating'], s=5)
plt.xlabel('Number of votes')
plt.ylabel('Rating')
plt.title('Correlation between number of votings and ratings')
plt.grid(True)
plt.show()

# %% [markdown]
# Level 3Task 3: Price Range vs. Online Delivery and
# Table Booking
# 1) Analyze if there is a relationship between the price range and the availability of online delivery and table booking.
# 2) Determine if higher-priced restaurants are more likely to offer these services.

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
import scipy.stats as stats

# %%
data = pd.read_csv(r"C:\Users\LENOVO\Downloads\Dataset .csv")

# %%
data
# Out:
#       Restaurant ID           Restaurant Name  Country Code              City  \
# 0           6317637          Le Petit Souffle           162       Makati City
# 1           6304287          Izakaya Kikufuji           162       Makati City
# 2           6300002    Heat - Edsa Shangri-La           162  Mandaluyong City
# 3           6318506                      Ooma           162  Mandaluyong City
# 4           6314302               Sambo Kojin           162  Mandaluyong City
# ...             ...                       ...           ...               ...
# 9546        5915730               Naml۱ Gurme           208         ��stanbul
# 9547        5908749              Ceviz A��ac۱           208         ��stanbul
# 9548        5915807                     Huqqa           208         ��stanbul
# 9549        5916112               A���k Kahve           208         ��stanbul
# 9550        5927402  Walter's Coffee Roastery           208         ��stanbul
#
# ...

# %%
cross_tab_delivery = pd.crosstab(data['Price range'], data['Has Online delivery'])
cross_tab_booking = pd.crosstab(data['Price range'], data['Has Table booking'])

plt.figure(figsize=(8, 6))
sns.heatmap(cross_tab_delivery, annot=True, cmap='Blues')
plt.title('Price Range vs. Online Delivery Availablity')
plt.xlabel('Online Delivery')
plt.ylabel('Price Range')
plt.show()

plt.figure(figsize=(8, 6))
sns.heatmap(cross_tab_booking, annot=True, cmap='Blues')
plt.title('Price Range vs. Table Booking Availability')
plt.xlabel('Table Booking')
plt.ylabel('Price Range')
plt.show()

# %%
cross_tab_delivery = pd.crosstab(data['Price range'], data['Has Online delivery'])

cross_tab_booking = pd.crosstab(data['Price range'], data['Has Table booking'])

chi2_delivery, p_value_delivery, _, _ = stats.chi2_contingency(cross_tab_delivery)

chi2_booking, p_value_booking, _, _ = stats.chi2_contingency(cross_tab_booking)

alpha = 0.05

higher_priced_delivery = p_value_delivery < alpha
higher_priced_booking = p_value_booking < alpha

print("Are higher-priced restaurants more likely to offer online Delivery?" , higher_priced_delivery)
print("Are higher-priced restaurants more likely to offer table Booking?" , higher_priced_booking)
# Out:
# Are higher-priced restaurants more likely to offer online Delivery? True
# Are higher-priced restaurants more likely to offer table Booking? True
